# %%
# add path:
data_path = '../DRIVE_dataset/datasets/'

# check if data_path exists:
import os

if not os.path.exists(data_path):
    print("Please update your data path to an existing folder.")
elif not set(["training", "test"]).issubset(set(os.listdir(data_path))):
    print("Please update your data path to the correct folder (should contain train and test folders).")
else:
    print("Congrats! You selected the correct folder :)")
        
# Install additional packages 
#!pip install scikit-image
#!pip install wandb
#!pip install monai==1.2.0        
import os
import numpy as np
import matplotlib.pyplot as plt
import glob
import monai
from PIL import Image
import torch
from monai.transforms import Transform
from monai.transforms import Compose, Flipd, Rotate90d, RandFlipd, RandRotate90d, RandSpatialCropd
import warnings
warnings.filterwarnings("ignore")
from monai.data import CacheDataset, DataLoader

### our modules
from dataset import *
from training import *
from testing import *
from preprocessing import *
from unetWithDropout import * 
####
# Out:
# Congrats! You selected the correct folder :)
# 2025-03-23 10:46:49.857014: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-23 10:46:49.915348: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-23 10:46:49.915379: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-23 10:46:49.915440: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-23 10:46:49.925646: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-23 10:46:51.052476: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Create Dataset and plot first image

# %%
train_dict_list = build_dict_vessels(data_path, mode='training')
test_dict_list = build_dict_vessels(data_path, mode='test')

print(f'Number of samples in the training dataset: {len(train_dict_list)}')
print(f'Number of samples in the test dataset: {len(test_dict_list)}')

#train_dataset = monai.data.CacheDataset(train_dict_list, transform=LoadVesselData())
#test_dataset = monai.data.CacheDataset(test_dict_list, transform=LoadVesselData())

#for i in range(1):
#    visualize_vessel_sample(train_dataset[i], title=f"Sample {i+1}")
# Out:
# Number of samples in the training dataset: 20
# Number of samples in the test dataset: 20

# %% [markdown]
# # Data Augmentation

# %%
# extracting the list of paths to the tif images
train_img_list = [d.get("img") for d in train_dict_list if "img" in d]
print('Sample from train_img_list')
print(train_img_list[0])
test_img_list = [d.get("img") for d in test_dict_list if "img" in d]
print('Sample from test_img_list')
print(test_img_list[0])
# Out:
# Sample from train_img_list
# ../DRIVE_dataset/datasets/training/images/21_training.tif
# Sample from test_img_list
# ../DRIVE_dataset/datasets/test/images/01_test.tif

# %%
# installing the necessary package
# !pip install imagecodecs
# !pip install opencv-python

train_processed_list = image_preprocessing(train_img_list, 'train')

# temporary just for testing purposes
#first_two_img_list = train_img_list[:2]
#print(first_two_img_list)
#train_processed_list = image_preprocessing(first_two_img_list, 'train')

# substituiting the images in the dictionaries
for new_img, d in zip(train_processed_list, train_dict_list):
    d["img"] = new_img
    
# checking the computation    
for d in train_dict_list:
    print(d)
    break
    
# doing the same for test data
test_processed_list = image_preprocessing(test_img_list, 'test')

# substituiting the images in the dictionaries
for new_img, d in zip(test_processed_list, test_dict_list):
    d["img"] = new_img
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imagecodecs in /home/jovyan/.local/lib/python3.10/site-packages (2024.12.30)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imagecodecs) (1.26.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /home/jovyan/.local/lib/python3.10/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)
# Saving computation in folder ../CLAHE_dataset/train
# Image 21 is (584, 565), float64
# Processed image : 21 → Saved to ../CLAHE_dataset/train/clahe_21.tif
# Image 22 is (584, 565), float64
# Processed image : 22 → Saved to ../CLAHE_dataset/train/clahe_22.tif
# Image 23 is (584, 565), float64
# Processed image : 23 → Saved to ../CLAHE_dataset/train/clahe_23.tif
# Image 24 is (584, 565), float64
# Processed image : 24 → Saved to ../CLAHE_dataset/train/clahe_24.tif
# Image 25 is (584, 565), float64
# Processed image : 25 → Saved to ../CLAHE_dataset/train/clahe_25.tif
# Image 26 is (584, 565), float64
# Processed image : 26 → Saved to ../CLAHE_dataset/train/clahe_26.tif
# Image 27 is (584, 565), float64
# Processed image : 27 → Saved to ../CLAHE_dataset/train/clahe_27.tif
# Image 28 is (584, 565), float64
# Processed image : 28 → Saved to ../CLAHE_dataset/train/clahe_28.tif
# Image 29 is (584, 565), float64
# Processed image : 29 → Saved to ../CLAHE_dataset/train/clahe_29.tif
# Image 30 is (584, 565), float64
# Processed image : 30 → Saved to ../CLAHE_dataset/train/clahe_30.tif
# Image 31 is (584, 565), float64
# Processed image : 31 → Saved to ../CLAHE_dataset/train/clahe_31.tif
# Image 32 is (584, 565), float64
# Processed image : 32 → Saved to ../CLAHE_dataset/train/clahe_32.tif
# Image 33 is (584, 565), float64
# Processed image : 33 → Saved to ../CLAHE_dataset/train/clahe_33.tif
# Image 34 is (584, 565), float64
# Processed image : 34 → Saved to ../CLAHE_dataset/train/clahe_34.tif
# Image 35 is (584, 565), float64
# Processed image : 35 → Saved to ../CLAHE_dataset/train/clahe_35.tif
# Image 36 is (584, 565), float64
# Processed image : 36 → Saved to ../CLAHE_dataset/train/clahe_36.tif
# Image 37 is (584, 565), float64
# Processed image : 37 → Saved to ../CLAHE_dataset/train/clahe_37.tif
# Image 38 is (584, 565), float64
# Processed image : 38 → Saved to ../CLAHE_dataset/train/clahe_38.tif
# Image 39 is (584, 565), float64
# Processed image : 39 → Saved to ../CLAHE_dataset/train/clahe_39.tif
# Image 40 is (584, 565), float64
# Processed image : 40 → Saved to ../CLAHE_dataset/train/clahe_40.tif
# All images processed with customized CLAHE.
# ['../CLAHE_dataset/train/clahe_21.tif', '../CLAHE_dataset/train/clahe_22.tif', '../CLAHE_dataset/train/clahe_23.tif', '../CLAHE_dataset/train/clahe_24.tif', '../CLAHE_dataset/train/clahe_25.tif', '../CLAHE_dataset/train/clahe_26.tif', '../CLAHE_dataset/train/clahe_27.tif', '../CLAHE_dataset/train/clahe_28.tif', '../CLAHE_dataset/train/clahe_29.tif', '../CLAHE_dataset/train/clahe_30.tif', '../CLAHE_dataset/train/clahe_31.tif', '../CLAHE_dataset/train/clahe_32.tif', '../CLAHE_dataset/train/clahe_33.tif', '../CLAHE_dataset/train/clahe_34.tif', '../CLAHE_dataset/train/clahe_35.tif', '../CLAHE_dataset/train/clahe_36.tif', '../CLAHE_dataset/train/clahe_37.tif', '../CLAHE_dataset/train/clahe_38.tif', '../CLAHE_dataset/train/clahe_39.tif', '../CLAHE_dataset/train/clahe_40.tif']
# Saving computation in folder ../Halfwave_dataset/train
# Processed image : 21 → Saved to ../Halfwave_dataset/train/halfwave_21.tif
# Processed image : 22 → Saved to ../Halfwave_dataset/train/halfwave_22.tif
# Processed image : 23 → Saved to ../Halfwave_dataset/train/halfwave_23.tif
# Processed image : 24 → Saved to ../Halfwave_dataset/train/halfwave_24.tif
# Processed image : 25 → Saved to ../Halfwave_dataset/train/halfwave_25.tif
# Processed image : 26 → Saved to ../Halfwave_dataset/train/halfwave_26.tif
# Processed image : 27 → Saved to ../Halfwave_dataset/train/halfwave_27.tif
# Processed image : 28 → Saved to ../Halfwave_dataset/train/halfwave_28.tif
# Processed image : 29 → Saved to ../Halfwave_dataset/train/halfwave_29.tif
# Processed image : 30 → Saved to ../Halfwave_dataset/train/halfwave_30.tif
# Processed image : 31 → Saved to ../Halfwave_dataset/train/halfwave_31.tif
# Processed image : 32 → Saved to ../Halfwave_dataset/train/halfwave_32.tif
# Processed image : 33 → Saved to ../Halfwave_dataset/train/halfwave_33.tif
# Processed image : 34 → Saved to ../Halfwave_dataset/train/halfwave_34.tif
# Processed image : 35 → Saved to ../Halfwave_dataset/train/halfwave_35.tif
# Processed image : 36 → Saved to ../Halfwave_dataset/train/halfwave_36.tif
# Processed image : 37 → Saved to ../Halfwave_dataset/train/halfwave_37.tif
# Processed image : 38 → Saved to ../Halfwave_dataset/train/halfwave_38.tif
# Processed image : 39 → Saved to ../Halfwave_dataset/train/halfwave_39.tif
# Processed image : 40 → Saved to ../Halfwave_dataset/train/halfwave_40.tif
# Halfwave rectification completed for all images.
# ['../Halfwave_dataset/train/halfwave_21.tif', '../Halfwave_dataset/train/halfwave_22.tif', '../Halfwave_dataset/train/halfwave_23.tif', '../Halfwave_dataset/train/halfwave_24.tif', '../Halfwave_dataset/train/halfwave_25.tif', '../Halfwave_dataset/train/halfwave_26.tif', '../Halfwave_dataset/train/halfwave_27.tif', '../Halfwave_dataset/train/halfwave_28.tif', '../Halfwave_dataset/train/halfwave_29.tif', '../Halfwave_dataset/train/halfwave_30.tif', '../Halfwave_dataset/train/halfwave_31.tif', '../Halfwave_dataset/train/halfwave_32.tif', '../Halfwave_dataset/train/halfwave_33.tif', '../Halfwave_dataset/train/halfwave_34.tif', '../Halfwave_dataset/train/halfwave_35.tif', '../Halfwave_dataset/train/halfwave_36.tif', '../Halfwave_dataset/train/halfwave_37.tif', '../Halfwave_dataset/train/halfwave_38.tif', '../Halfwave_dataset/train/halfwave_39.tif', '../Halfwave_dataset/train/halfwave_40.tif']
# {'img': '../Halfwave_dataset/train/halfwave_21.tif', 'mask': '../DRIVE_dataset/datasets/training/1st_manual/21_manual1.gif'}
# Saving computation in folder ../CLAHE_dataset/test
# Image 1 is (584, 565), float64
# Processed image : 1 → Saved to ../CLAHE_dataset/test/clahe_1.tif
# Image 2 is (584, 565), float64
# Processed image : 2 → Saved to ../CLAHE_dataset/test/clahe_2.tif
# Image 3 is (584, 565), float64
# Processed image : 3 → Saved to ../CLAHE_dataset/test/clahe_3.tif
# Image 4 is (584, 565), float64
# Processed image : 4 → Saved to ../CLAHE_dataset/test/clahe_4.tif
# Image 5 is (584, 565), float64
# Processed image : 5 → Saved to ../CLAHE_dataset/test/clahe_5.tif
# Image 6 is (584, 565), float64
# Processed image : 6 → Saved to ../CLAHE_dataset/test/clahe_6.tif
# Image 7 is (584, 565), float64
# Processed image : 7 → Saved to ../CLAHE_dataset/test/clahe_7.tif
# Image 8 is (584, 565), float64
# Processed image : 8 → Saved to ../CLAHE_dataset/test/clahe_8.tif
# Image 9 is (584, 565), float64
# Processed image : 9 → Saved to ../CLAHE_dataset/test/clahe_9.tif
# Image 10 is (584, 565), float64
# Processed image : 10 → Saved to ../CLAHE_dataset/test/clahe_10.tif
# Image 11 is (584, 565), float64
# Processed image : 11 → Saved to ../CLAHE_dataset/test/clahe_11.tif
# Image 12 is (584, 565), float64
# Processed image : 12 → Saved to ../CLAHE_dataset/test/clahe_12.tif
# Image 13 is (584, 565), float64
# Processed image : 13 → Saved to ../CLAHE_dataset/test/clahe_13.tif
# Image 14 is (584, 565), float64
# Processed image : 14 → Saved to ../CLAHE_dataset/test/clahe_14.tif
# Image 15 is (584, 565), float64
# Processed image : 15 → Saved to ../CLAHE_dataset/test/clahe_15.tif
# Image 16 is (584, 565), float64
# Processed image : 16 → Saved to ../CLAHE_dataset/test/clahe_16.tif
# Image 17 is (584, 565), float64
# Processed image : 17 → Saved to ../CLAHE_dataset/test/clahe_17.tif
# Image 18 is (584, 565), float64
# Processed image : 18 → Saved to ../CLAHE_dataset/test/clahe_18.tif
# Image 19 is (584, 565), float64
# Processed image : 19 → Saved to ../CLAHE_dataset/test/clahe_19.tif
# Image 20 is (584, 565), float64
# Processed image : 20 → Saved to ../CLAHE_dataset/test/clahe_20.tif
# All images processed with customized CLAHE.
# ['../CLAHE_dataset/test/clahe_1.tif', '../CLAHE_dataset/test/clahe_2.tif', '../CLAHE_dataset/test/clahe_3.tif', '../CLAHE_dataset/test/clahe_4.tif', '../CLAHE_dataset/test/clahe_5.tif', '../CLAHE_dataset/test/clahe_6.tif', '../CLAHE_dataset/test/clahe_7.tif', '../CLAHE_dataset/test/clahe_8.tif', '../CLAHE_dataset/test/clahe_9.tif', '../CLAHE_dataset/test/clahe_10.tif', '../CLAHE_dataset/test/clahe_11.tif', '../CLAHE_dataset/test/clahe_12.tif', '../CLAHE_dataset/test/clahe_13.tif', '../CLAHE_dataset/test/clahe_14.tif', '../CLAHE_dataset/test/clahe_15.tif', '../CLAHE_dataset/test/clahe_16.tif', '../CLAHE_dataset/test/clahe_17.tif', '../CLAHE_dataset/test/clahe_18.tif', '../CLAHE_dataset/test/clahe_19.tif', '../CLAHE_dataset/test/clahe_20.tif']
# Saving computation in folder ../Halfwave_dataset/test
# Processed image : 1 → Saved to ../Halfwave_dataset/test/halfwave_1.tif
# Processed image : 2 → Saved to ../Halfwave_dataset/test/halfwave_2.tif
# Processed image : 3 → Saved to ../Halfwave_dataset/test/halfwave_3.tif
# Processed image : 4 → Saved to ../Halfwave_dataset/test/halfwave_4.tif
# Processed image : 5 → Saved to ../Halfwave_dataset/test/halfwave_5.tif
# Processed image : 6 → Saved to ../Halfwave_dataset/test/halfwave_6.tif
# Processed image : 7 → Saved to ../Halfwave_dataset/test/halfwave_7.tif
# Processed image : 8 → Saved to ../Halfwave_dataset/test/halfwave_8.tif
# Processed image : 9 → Saved to ../Halfwave_dataset/test/halfwave_9.tif
# Processed image : 10 → Saved to ../Halfwave_dataset/test/halfwave_10.tif
# Processed image : 11 → Saved to ../Halfwave_dataset/test/halfwave_11.tif
# Processed image : 12 → Saved to ../Halfwave_dataset/test/halfwave_12.tif
# Processed image : 13 → Saved to ../Halfwave_dataset/test/halfwave_13.tif
# Processed image : 14 → Saved to ../Halfwave_dataset/test/halfwave_14.tif
# Processed image : 15 → Saved to ../Halfwave_dataset/test/halfwave_15.tif
# Processed image : 16 → Saved to ../Halfwave_dataset/test/halfwave_16.tif
# Processed image : 17 → Saved to ../Halfwave_dataset/test/halfwave_17.tif
# Processed image : 18 → Saved to ../Halfwave_dataset/test/halfwave_18.tif
# Processed image : 19 → Saved to ../Halfwave_dataset/test/halfwave_19.tif
# Processed image : 20 → Saved to ../Halfwave_dataset/test/halfwave_20.tif
# Halfwave rectification completed for all images.
# ['../Halfwave_dataset/test/halfwave_1.tif', '../Halfwave_dataset/test/halfwave_2.tif', '../Halfwave_dataset/test/halfwave_3.tif', '../Halfwave_dataset/test/halfwave_4.tif', '../Halfwave_dataset/test/halfwave_5.tif', '../Halfwave_dataset/test/halfwave_6.tif', '../Halfwave_dataset/test/halfwave_7.tif', '../Halfwave_dataset/test/halfwave_8.tif', '../Halfwave_dataset/test/halfwave_9.tif', '../Halfwave_dataset/test/halfwave_10.tif', '../Halfwave_dataset/test/halfwave_11.tif', '../Halfwave_dataset/test/halfwave_12.tif', '../Halfwave_dataset/test/halfwave_13.tif', '../Halfwave_dataset/test/halfwave_14.tif', '../Halfwave_dataset/test/halfwave_15.tif', '../Halfwave_dataset/test/halfwave_16.tif', '../Halfwave_dataset/test/halfwave_17.tif', '../Halfwave_dataset/test/halfwave_18.tif', '../Halfwave_dataset/test/halfwave_19.tif', '../Halfwave_dataset/test/halfwave_20.tif']

# %%
train_transforms = Compose([
    LoadVesselData()
])
train_dataset = monai.data.CacheDataset(
    data=train_dict_list, 
    transform = train_transforms
)
# Out:
# Loading dataset: 100%|██████████| 20/20 [00:00<00:00, 43.14it/s]

# %%
for i in range(1):
    visualize_vessel_sample(train_dataset[i], title=f"Sample {i+1}")
    
    
train_dataset, val_dataset = split_dataset(train_dataset, train_ratio=0.8)

train_dataloader = DataLoader(train_dataset, batch_size=5, shuffle=True)
print(type(train_dataloader))
validation_loader = DataLoader(val_dataset, batch_size=5, shuffle=True)
# Out:
# Dataset split: 16 training samples, 4 testing samples.
# <class 'monai.data.dataloader.DataLoader'>

# %%
for batch_data in train_dataloader:
    print("Image shape:", batch_data["img"].shape)  # Expected: [batch_size, 1, 512, 512]
    break
# Out:
# Image shape: torch.Size([5, 1, 512, 512])

# %% [markdown]
# # Models

# %%
# Setting up the neural network
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'The used device is {device}')

model = monai.networks.nets.UNet(
    spatial_dims=2,
    in_channels=1,
    out_channels=1,
    channels=(8, 16, 32, 64, 128),
    strides=(2, 2, 2, 2),
    num_res_units=2,
).to(device)

n = sum(p.numel() for p in model.parameters() if p.requires_grad) # number of parameters

loss_function =  monai.losses.DiceLoss(sigmoid=True, batch=True)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# The used device is cuda

# %% [markdown]
# # Training

# %%
# Setting up the training loop
def from_compose_to_list(transform):
    return transform.transforms

from tqdm import tqdm
import wandb

run = wandb.init(
    project='DRIVE',
    name='03-03-25',
    config={
        'loss function': str(loss_function), 
        'lr': optimizer.param_groups[0]["lr"],
        'transform': from_compose_to_list(train_transforms),
        'batch_size': train_dataloader.batch_size,
        'layers': 5,
        'parameters': n    
    }
)

run_id = run.id # We remember here the run ID to be able to write the evaluation metrics

### training loop
## ADD DICE
train(model, train_dataloader, validation_loader, optimizer,loss_function,n, device)
    
    
# Store the network parameters        
torch.save(model.state_dict(), r'trainedUNet.pt')
run.finish()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: camilla-balzarotti02 (camilla-balzarotti02-univeristy-of-twente) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jovyan/Deep-learning for medical image analysis/deep-learning-med/project/wandb/run-20250323_104746-4div252v</code>
# Syncing run <strong><a href='https://wandb.ai/camilla-balzarotti02-univeristy-of-twente/DRIVE/runs/4div252v' target="_blank">03-03-25</a></strong> to <a href='https://wandb.ai/camilla-balzarotti02-univeristy-of-twente/DRIVE' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/camilla-balzarotti02-univeristy-of-twente/DRIVE' target="_blank">https://wandb.ai/camilla-balzarotti02-univeristy-of-twente/DRIVE</a>
#  View run at <a href='https://wandb.ai/camilla-balzarotti02-univeristy-of-twente/DRIVE/runs/4div252v' target="_blank">https://wandb.ai/camilla-balzarotti02-univeristy-of-twente/DRIVE/runs/4div252v</a>
# 100%|██████████| 200/200 [04:49<00:00,  1.45s/it]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇█</td></tr><tr><td>pixelaccuracy</td><td>▁▂▃▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇████████</td></tr><tr><td>train_loss</td><td>███▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▅▅▅▅▅▅▅▄▄▄▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▇▇▇▇▆▆▆▆▆▆▆▅▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>199</td></tr><tr><td>pixelaccuracy</td><td>0.94214</td></tr><tr><td>train_loss</td><td>0.19914</td></tr><tr><td>val_loss</td><td>0.38738</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">03-03-25</strong> at: <a href='https://wandb.ai/camilla-balzarotti02-univeristy-of-twente/DRIVE/runs/4div252v' target="_blank">https://wandb.ai/camilla-balzarotti02-univeristy-of-twente/DRIVE/runs/4div252v</a><br> View project at: <a href='https://wandb.ai/camilla-balzarotti02-univeristy-of-twente/DRIVE' target="_blank">https://wandb.ai/camilla-balzarotti02-univeristy-of-twente/DRIVE</a><br>Synced 5 W&B file(s), 2400 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250323_104746-4div252v/logs</code>

# %%
api = wandb.Api()
run = api.run(f"DRIVE/{run_id}")

# %%
# Dice
metric_fn = monai.metrics.DiceMetric()
dice = compute_metric(validation_loader, model, metric_fn,device)
run.summary["dice"] = dice
run.summary.update()
print(f"Dice on validation set: {dice:.3f}")
# Out:
# Dice on validation set: 0.620

# %%
# Hausdorff distance
metric_fn = monai.metrics.HausdorffDistanceMetric()
HausdorffDistance = compute_metric(validation_loader, model, metric_fn,device)
run.summary["HausdorffDistance"] = HausdorffDistance
run.summary.update()
print(f"HausdorffDistance on test set: {HausdorffDistance:.3f}")
# Out:
# HausdorffDistance on test set: 49.148

# %% [markdown]
# ## Other models

# %%
# Modified UNet without dropout
modified_UNet = monai.networks.nets.UNet(
    spatial_dims=2,
    in_channels=1,
    out_channels=1,
    channels=(8, 16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2, 2),
    num_res_units=3,
    norm = 'BATCH',
).to(device)

# %%
dropout_UNet = UNetWithDropout(
    in_channels=1,
    out_channels=1,
    features=(16, 32, 64, 128, 256),
    dropout_prob=0.3
).to(device)

# %%
swin_model = monai.networks.nets.SwinUNETR(
    img_size = (512, 512, 512),
    in_channels = 1,
    out_channels = 1,
    feature_size = 48,
    use_checkpoint = True
).to(device)

# %% [markdown]
# # Test

# %%
# Test dataset for now obtained from the training one (train_dict_list in monai.data.CacheDataset to obtain test_dataset) bacause the test dataset does not have useful masks
test_transform = monai.transforms.Compose([
    LoadVesselData(),  # ensures float32
    #monai.transforms.AddChanneld(keys=['img'])   #, 'mask']),
        #monai.transforms.ScaleIntensityd(keys=['img'],minv=0, maxv=1),
        #monai.transforms.Zoomd(keys=['img', 'mask'], zoom=0.25, keep_size=False, mode=['bilinear', 'nearest']),
    ###monai.transforms.EnsureTyped(keys=['img', 'mask'], dtype=torch.float32),  # Explicitly convert
])


test_dataset = monai.data.CacheDataset(test_dict_list, transform=test_transform)
test_loader = monai.data.DataLoader(test_dataset, batch_size=1)


for sample in test_loader:
    print("Test Image dtype:", sample["img"].dtype)  # Should be torch.float32
    #print("Test Mask dtype:", sample["mask"].dtype)  # Should be torch.float32
    print("Test Image shape:", sample["img"].shape)  # Should be [1, 1, 512, 512]
    break


for sample in test_loader:
    visual_evaluation_nomask(sample, model,device)
    break
# Out:
# Loading dataset: 100%|██████████| 20/20 [00:00<00:00, 56.22it/s]
# Test Image dtype: torch.float32
# Test Image shape: torch.Size([1, 1, 512, 512])

# %%
test_outputs = compute_test_predictions(test_loader, model, device)
print(f"Test set predictions computed for {len(test_outputs)} images")
# Out:
# Test set predictions computed for 20 images

# %%
"""TO DO"""
# Dice
# metric_fn = monai.metrics.DiceMetric()
# dice = compute_metric(test_loader, model, metric_fn,device)
#run.summary["dice"] = dice
#run.summary.update()
print(f"Dice on test set: {dice:.3f}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Dice
#       2 metric_fn = monai.metrics.DiceMetric()
# ----> 3 dice = compute_metric(test_dataloader, model, metric_fn,device)
#       4 #run.summary["dice"] = dice
#       5 #run.summary.update()
#       6 print(f"Dice on test set: {dice:.3f}")
#
# File ~/Deep-learning for medical image analysis/deep-learning-med/project/testing.py:76, in compute_metric(dataloader, model, metric_fn, device)
#      74     with torch.no_grad():
#      75         output = discrete_transform(Sigmoid(inferer(sample['img'].to(device), network=model).cpu()))
# ---> 76         metric_value = metric_fn(output, sample["mask"]) # this returns a tensor
#      78         mean_value.append(metric_value) # store tensors
#      80 mean_value = torch.cat(mean_value).mean().item()
#
# KeyError: 'mask'

# %%
# Hausdorff distance
# metric_fn = monai.metrics.HausdorffDistanceMetric()
# HausdorffDistance = compute_metric(test_loader, model, metric_fn,device)
# run.summary["HausdorffDistance"] = HausdorffDistance
# run.summary.update()
# print(f"HausdorffDistance on test set: {HausdorffDistance:.3f}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Hausdorff distance
#       2 metric_fn = monai.metrics.HausdorffDistanceMetric()
# ----> 3 HausdorffDistance = compute_metric(test_dataloader, model, metric_fn,device)
#       4 run.summary["HausdorffDistance"] = HausdorffDistance
#       5 run.summary.update()
#
# File ~/Deep-learning for medical image analysis/deep-learning-med/project/testing.py:76, in compute_metric(dataloader, model, metric_fn, device)
#      74     with torch.no_grad():
#      75         output = discrete_transform(Sigmoid(inferer(sample['img'].to(device), network=model).cpu()))
# ---> 76         metric_value = metric_fn(output, sample["mask"]) # this returns a tensor
#      78         mean_value.append(metric_value) # store tensors
#      80 mean_value = torch.cat(mean_value).mean().item()
#
# KeyError: 'mask'
